# %%
import pandas as pd
import pickle
from sklearn.ensemble import RandomForestClassifier

# %%
train = pd.read_pickle("train.pkl").drop("ID_code", axis=1)
test = pd.read_pickle("test.pkl")
test_id = test['ID_code'].values
test.drop(['ID_code'], axis=1, inplace=True)

# %%
clf = RandomForestClassifier(n_estimators=100, max_depth=6,
                              random_state=0)

# %%
X = train.drop('target', axis=1)
y = train.target
clf.fit(X, y)
# Out:
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=6, max_features='auto', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators=100, n_jobs=None,
#             oob_score=False, random_state=0, verbose=0, warm_start=False)

# %%
feat_import = dict(zip(X.columns, clf.feature_importances_))
feat_import = pd.DataFrame.from_dict(feat_import, orient='index')
feat_import.columns = ['importances']
feat_import = (feat_import/feat_import.max())
feat_import.sort_values(by=['importances'], ascending=False)
# Out:
#          importances
# var_81      1.000000
# var_139     0.900019
# var_12      0.755202
# var_26      0.529088
# var_174     0.511921
# var_166     0.481693
# var_53      0.476194
# var_110     0.451504
# var_109     0.418885
# var_146     0.411904
# var_22      0.378332
# var_80      0.371201
# var_6       0.351133
# var_190     0.227154
# var_13      0.220391
# var_99      0.213033
# var_0       0.211012
# var_164     0.210807
# var_133     0.207793
# var_78      0.199188
# var_179     0.192308
# var_76      0.190158
# var_44      0.184569
# var_198     0.182616
# var_21      0.171303
# var_165     0.167943
# var_170     0.165250
# var_2       0.156998
# var_40      0.154823
# var_148     0.146698
# ...              ...
# var_54      0.007131
# var_45      0.007110
# var_136     0.007106
# var_129     0.007047
# var_38      0.006990
# var_152     0.006847
# var_126     0.006698
# var_140     0.006681
# var_41      0.006676
# var_61      0.006579
# var_72      0.006565
# ...
